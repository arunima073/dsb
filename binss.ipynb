# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("nba.csv")

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457                NaN        NaN
#
# [458 rows x 9 columns]>

# %%
df.info
# Out:
# <bound method DataFrame.info of               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457                NaN        NaN
#
# [458 rows x 9 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df['Height'].value_counts()
# Out:
# 6-9     59
# 6-10    47
# 6-7     45
# 6-8     43
# 6-6     42
# 6-11    40
# 6-3     33
# 6-5     32
# 6-4     29
# 7-0     27
# 6-1     16
# 6-2     16
# 6-0     10
# 7-1      7
# 7-3      4
# 7-2      3
# 5-11     3
# 5-9      1
# Name: Height, dtype: int64

# %%
df['Weight'].value_counts()
# Out:
# 220.0    29
# 240.0    28
# 250.0    26
# 200.0    25
# 205.0    22
#          ..
# 278.0     1
# 223.0     1
# 227.0     1
# 289.0     1
# 170.0     1
# Name: Weight, Length: 87, dtype: int64

# %%
heightgrp=df.groupby(df['Height'])

# %%
heightgrp.get_group('6-0')
# Out:
#                 Name                  Team  Number Position   Age Height  \
# 47     Isaiah Canaan    Philadelphia 76ers     0.0       PG  25.0    6-0
# 57         Ish Smith    Philadelphia 76ers     1.0       PG  27.0    6-0
# 67        Kyle Lowry       Toronto Raptors     7.0       PG  30.0    6-0
# 100       Chris Paul  Los Angeles Clippers     3.0       PG  31.0    6-0
# 142  Darren Collison      Sacramento Kings     7.0       PG  28.0    6-0
# 152     Aaron Brooks         Chicago Bulls     0.0       PG  31.0    6-0
# 228       J.J. Barea      Dallas Mavericks     5.0       PG  31.0    6-0
# 305      Patty Mills     San Antonio Spurs     8.0       PG  27.0    6-0
# 384    D.J. Augustin        Denver Nuggets    12.0       PG  28.0    6-0
# 394    Jameer Nelson        Denver Nuggets     1.0       PG  34.0    6-0
#
#      Weight         College      Salary
# 47    201.0    Murray State    947276.0
# 57    175.0     Wake Forest    947276.0
# 67    205.0       Villanova  12000000.0
# 100   175.0     Wake Forest  21468695.0
# 142   175.0            UCLA   5013559.0
# 152   161.0          Oregon   2250000.0
# 228   185.0    Northeastern   4290000.0
# 305   185.0    Saint Mary's   3578947.0
# 384   183.0           Texas   3000000.0
# 394   190.0  Saint Joseph's   4345000.0

# %%
weightgrp=df.groupby(df['Weight'])

# %%
weightgrp

# %%
type(weightgrp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
weightgrp.dtypes
# Out:
#           Name    Team   Number Position      Age  Height College   Salary
# Weight
# 161.0   object  object  float64   object  float64  object  object  float64
# 165.0   object  object  float64   object  float64  object  object  float64
# 169.0   object  object  float64   object  float64  object  object  float64
# 170.0   object  object  float64   object  float64  object  object  float64
# 172.0   object  object  float64   object  float64  object  object  float64
# ...        ...     ...      ...      ...      ...     ...     ...      ...
# 279.0   object  object  float64   object  float64  object  object  float64
# 280.0   object  object  float64   object  float64  object  object  float64
# 289.0   object  object  float64   object  float64  object  object  float64
# 290.0   object  object  float64   object  float64  object  object  float64
# 307.0   object  object  float64   object  float64  object  object  float64
#
# [87 rows x 8 columns]

# %%
bins=[19,25,31,36,40]
labels=['19-24','25-30','31-35','36-40']
df['Agegrp']=pd.cut(df['Age'],bins=bins,labels=labels,right=False)

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary Agegrp
# 0              Texas  7730337.0  25-30
# 1          Marquette  6796117.0  25-30
# 2  Boston University        NaN  25-30
# 3      Georgia State  1148640.0  19-24
# 4                NaN  5000000.0  25-30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
#  9   Agegrp    454 non-null    category
# dtypes: category(1), float64(4), object(5)
# memory usage: 33.0+ KB

# %%
df['Agegrp'].value_counts()
# Out:
# 25-30    212
# 19-24    154
# 31-35     68
# 36-40     20
# Name: Agegrp, dtype: int64

# %%
df.groupby('Agegrp')['Salary'].max()
# Out:
# Agegrp
# 19-24    16407501.0
# 25-30    22359364.0
# 31-35    22970500.0
# 36-40    25000000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Agegrp')['Salary'].min()
# Out:
# Agegrp
# 19-24     30888.0
# 25-30     55722.0
# 31-35    200600.0
# 36-40    222888.0
# Name: Salary, dtype: float64

# %%
df.groupby('Agegrp')['Salary'].std()
# Out:
# Agegrp
# 19-24    3.188468e+06
# 25-30    5.535586e+06
# 31-35    6.281446e+06
# 36-40    5.516191e+06
# Name: Salary, dtype: float64

# %%
df.groupby('Agegrp')['Salary'].mean()
# Out:
# Agegrp
# 19-24    2.706212e+06
# 25-30    5.895838e+06
# 31-35    6.662026e+06
# 36-40    3.847918e+06
# Name: Salary, dtype: float64

# %%
df.groupby('Agegrp')['Salary'].count()
# Out:
# Agegrp
# 19-24    150
# 25-30    207
# 31-35     67
# 36-40     19
# Name: Salary, dtype: int64

# %%
salary_list=list(df.groupby('Agegrp')['Salary'])
salary_list
# Out:
# [('19-24',
#   3       1148640.0
#   6       1170960.0
#   8       1824360.0
#   9       3431040.0
#   10      2569260.0
#             ...
#   446    12000000.0
#   447     1175880.0
#   449     1348440.0
#   452     2239800.0
#   454      900000.0
#   Name: Salary, Length: 154, dtype: float64),
#  ('25-30',
#   0       7730337.0
#   1       6796117.0
#   2             NaN
#   4       5000000.0
#   5      12000000.0
#             ...
#   450     2050000.0
#   451      981348.0
#   453     2433333.0
#   455     2900000.0
#   456      947276.0
#   Name: Salary, Length: 212, dtype: float64),
#  ('31-35',
#   19      6300000.0
#   31      1635476.0
#   33     22875000.0
#   34      7402812.0
#   43       947276.0
#             ...
#   375    13000000.0
#   394     4345000.0
#   413     3750000.0
#   415     3135000.0
#   434     5016000.0
#   Name: Salary, Length: 68, dtype: float64),
#  ('36-40',
#   46            NaN
#   72      2900000.0
#   93      5675000.0
#   101     3376000.0
#   102      947726.0
#   109    25000000.0
#   119      947276.0
#   139     1449187.0
#   183     2170465.0
#   236     8333334.0
#   256      947276.0
#   259     5000000.0
#   260     3542500.0
#   261     4088019.0
#   296      947276.0
#   299     2814000.0
#   343     2854940.0
#   392      947276.0
#   406      947276.0
#   420      222888.0
#   Name: Salary, dtype: float64)]

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary Agegrp
# 0                Texas  7730337.0  25-30
# 1            Marquette  6796117.0  25-30
# 2    Boston University        NaN  25-30
# 3        Georgia State  1148640.0  19-24
# 4                  NaN  5000000.0  25-30
# ..                 ...        ...    ...
# 453             Butler  2433333.0  25-30
# 454                NaN   900000.0  19-24
# 455                NaN  2900000.0  25-30
# 456             Kansas   947276.0  25-30
# 457                NaN        NaN    NaN
#
# [458 rows x 10 columns]

# %%
df.head(458)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary Agegrp
# 0                Texas  7730337.0  25-30
# 1            Marquette  6796117.0  25-30
# 2    Boston University        NaN  25-30
# 3        Georgia State  1148640.0  19-24
# 4                  NaN  5000000.0  25-30
# ..                 ...        ...    ...
# 453             Butler  2433333.0  25-30
# 454                NaN   900000.0  19-24
# 455                NaN  2900000.0  25-30
# 456             Kansas   947276.0  25-30
# 457                NaN        NaN    NaN
#
# [458 rows x 10 columns]
